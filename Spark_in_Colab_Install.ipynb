# %% [markdown]
# <a href="https://colab.research.google.com/github/kwabena55/Spark-for-Big-Data-and-Predictive-Analytics/blob/main/Spark_in_Colab_Install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  
# -*- coding: utf-8 -*----
"""Pyspark_Setup_with_Google_Colab.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1crDmdm4TrWo3RfQ4rx2MVNwJdAj6A9hL
"""

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz  #Unzip and install the spark file downloaded
# !pip install -q findspark  # Help find spark from GitHub and Set the System variable

# %%
# !ls /usr/lib/jvm # list the jdks available( you can see we installed the jdk-8)

# %%
# !pip install -U pyarrow  #helps in the srialization of sparkdataframe to pandas dataframe. This is optional. Will help you use python libraries in spark like numpy, matplotlib etc)

# %%
# 2. Setup Environment Variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"

# %%
# 3. Start Spark Session
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

#Create Dataframe
df = spark.createDataFrame([{"Spark on": "Jupyter"} for x in range(1000)])
df.show(1)
